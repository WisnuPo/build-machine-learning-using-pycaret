# %% [markdown]
# # **Learn PyCaret Library for Machine Learning Development**

# %%
from pycaret.classification import *
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('diabetes_prediction_dataset.csv')
data
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level
# 0              6.6                  140
# ...

# %%
data.describe().T
# Out:
#                         count        mean        std    min     25%     50%  \
# age                  100000.0   41.885856  22.516840   0.08   24.00   43.00
# hypertension         100000.0    0.074850   0.263150   0.00    0.00    0.00
# heart_disease        100000.0    0.039420   0.194593   0.00    0.00    0.00
# bmi                  100000.0   27.320767   6.636783  10.01   23.63   27.32
# HbA1c_level          100000.0    5.527507   1.070672   3.50    4.80    5.80
# blood_glucose_level  100000.0  138.058060  40.708136  80.00  100.00  140.00
#
#                         75%     max
# age                   60.00   80.00
# hypertension           0.00    1.00
# heart_disease          0.00    1.00
# bmi                   29.58   95.69
# HbA1c_level            6.20    9.00
# blood_glucose_level  159.00  300.00

# %%
train, test = train_test_split(data, test_size=0.2, random_state=42)

print('model trainnya adalah: ', train.shape)
print('model testnya adalah: ', test.shape)
# Out:
# model trainnya adalah:  (80000, 8)
# model testnya adalah:  (20000, 8)

# %%
data_model = setup(train, target='heart_disease', normalize=True, normalize_method='minmax')
# Out:
# <style type="text/css">
# #T_1c648_row9_col1, #T_1c648_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1c648">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c648_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1c648_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c648_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1c648_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1c648_row0_col1" class="data row0 col1" >3103</td>
#     </tr>
#     <tr>
#       <th id="T_1c648_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1c648_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1c648_row1_col1" class="data row1 col1" >heart_disease</td>
#     </tr>
#     <tr>
#       <th id="T_1c648_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              21:18:04
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_0b54f th {
#   text-align: left;
# }
# ...

# %%
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_1c4f3_row10_col0, #T_1c4f3_row10_col1, #T_1c4f3_row10_col2, #T_1c4f3_row10_col3, #T_1c4f3_row10_col4, #T_1c4f3_row10_col5, #T_1c4f3_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_1c4f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c4f3_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_1c4f3_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_1c4f3_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_1c4f3_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_1c4f3_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_1c4f3_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_1c4f3_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
lr_tuned = tune_model(lr)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
predict = predict_model(lr, data=test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_87bc4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87bc4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_87bc4_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_87bc4_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_87bc4_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_87bc4_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_87bc4_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_87bc4_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_87bc4_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87bc4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87bc4_row0_col0" class="data row0 col0" >Logistic Regression</td>
# ...
